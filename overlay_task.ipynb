# %%
from PIL import Image
import numpy as np
import os

# %% [markdown]
# # To Do
#
# ### - Standardize background images to certain size while maintaining aspect ratio
# ### - Make background of objects transparent

# %%
img = Image.open('Set 1/001a.jpg')
img = img.convert("RGBA")
datas = img.getdata()

newData = []
for item in datas:
    if item[0] >= 235 and item[1] >= 235 and item[2] >= 235:
        newData.append((255, 255, 255, 0))
    else:
        newData.append(item)

img.putdata(newData)
img.save("Set 1/001c.png", "PNG")
# Out:
# <PIL.Image.Image image mode=RGBA size=399x399 at 0x116E1D910>

# %%
img = Image.open('Set 1/002a.jpg')
img = img.convert("RGBA")
datas = img.getdata()

newData = []
for item in datas:
    if item[0] == 255 and item[1] == 255 and item[2] == 255:
        newData.append((255, 255, 255, 0))
    else:
        newData.append(item)
    #print(item)
#         if item[0] > 150:
#             newData.append((0, 0, 0, 255))
#         else:
#             newData.append(item)
            #print(item)
print(newData[0:100])
img.putdata(newData)
img.save("Set 1/001d.png", "PNG")
# Out:
# [(255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0), (255, 255, 255, 0
# ...

# %%
img = Image.open("Set 1/001d.png")
background = Image.open("/Users/arinchang/Desktop/MST_photos/011.jpg")

blended = Image.blend(img, background, alpha=0.5)
blended
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-10d9c53968d0> in <module>
#       2 background = Image.open("/Users/arinchang/Desktop/MST_photos/011.jpg")
#       3
# ----> 4 blended = Image.blend(img, background, alpha=0.5)
#       5 blended
#
# /opt/anaconda3/lib/python3.7/site-packages/PIL/Image.py in blend(im1, im2, alpha)
#    2858     im1.load()
#    2859     im2.load()
# -> 2860     return im1._new(core.blend(im1.im, im2.im, alpha))
#    2861
#    2862
#
# ValueError: images do not match

# %%
img = Image.open("Set 1/001d.png")
background = Image.open("/Users/arinchang/Desktop/MST_photos/011.jpg")
# background.resize(800, 1200)


# img.convert("RGBA")
# background.convert("RGBA")
print(img.getdata()[0])

background.paste(img, (0, 0))
background
# Out:
# (255, 255, 255, 0)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=860x577 at 0x117123BD0>

# %%
import cv2

overlay = cv2.imread('Set 1/001d.png')
background = cv2.imread('/Users/arinchang/Desktop/MST_photos/011.jpg')

added_image = cv2.addWeighted(background,0.4,overlay,0.1,0)

cv2.imwrite('combined.png', added_image)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-55-70a9abe96e39> in <module>
# ----> 1 import cv2
#       2
#       3 overlay = cv2.imread('Set 1/001d.png')
#       4 background = cv2.imread('/Users/arinchang/Desktop/MST_photos/011.jpg')
#       5
#
# ModuleNotFoundError: No module named 'cv2'
